# %% [markdown]
# # TP2- Introducción al SGBD MongoDB y Conexión a la API Rest de Twitter

# %% [markdown]
# En este trabajo práctico queremos descubrir las características del SGBD no relacional MongoDB. En este sentido, vamos a desarrollar un script que se conecta a la API Rest de Twitter para: 1) descargar datos al formato JSON, 2) almacenarlos en una base Mongo y 3) realizar algunas consultas sobre los datos.

# %% [markdown]
# ## 1. Conectarse a la API Rest de Twitter

# %% [markdown]
# - ¿Cómo crear una aplicación utilizando los datos de Twitter?: https://developer.twitter.com/en/docs/basics/getting-started
# - Crear una aplicación utilizando los datos de Twitter: https://apps.twitter.com/
# - ¿Qué deberían saber todos los desarrolladores antes de jugar con la API de twitter?: https://developer.twitter.com/en/docs/basics/things-every-developer-should-know

# %%
from twython import Twython

APP_KEY = 'Bln4nshEi6fcZZCe6wBWxRGCh'
APP_SECRET = 'Bmn9HUyJlS6WWalqqQgJH2cgXx308FRKT1EUZfzMWWswsDXHAR'
OAUTH_TOKEN = '2437781952-icfoETmCPDtEJXjkTMZ7OGU9UhcrYi2UCbXNnFF'
OAUTH_TOKEN_SECRET = 'Br1sua5udIHHzXDREVphc5GIaqgtTQ3e98mSG5dw9n6dV'

twitter = Twython(APP_KEY, APP_SECRET,OAUTH_TOKEN, OAUTH_TOKEN_SECRET)

# %%
twitter.update_status(status='See how easy using Twython is!')
# Out:
# {'contributors': None,
#  'coordinates': None,
#  'created_at': 'Wed Mar 28 13:57:11 +0000 2018',
#  'entities': {'hashtags': [], 'symbols': [], 'urls': [], 'user_mentions': []},
#  'favorite_count': 0,
#  'favorited': False,
#  'geo': None,
#  'id': 978994414260539392,
#  'id_str': '978994414260539392',
#  'in_reply_to_screen_name': None,
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'is_quote_status': False,
#  'lang': 'en',
#  'place': None,
#  'retweet_count': 0,
#  'retweeted': False,
#  'source': '<a href="http://www.uach.cl" rel="nofollow">MyAppTaller</a>',
#  'text': 'See how easy using Twython is!',
#  'truncated': False,
#  'user': {'contributors_enabled': False,
#   'created_at': 'Fri Apr 11 01:59:59 +0000 2014',
#   'default_profile': True,
#   'default_profile_image': False,
#   'description': '',
#   'entities': {'description': {'urls': []}},
#   'favourites_count': 57,
#   'follow_request_sent': False,
#   'followers_count': 7,
#   'following': False,
#   'friends_count': 102,
#   'geo_enabled': False,
#   'has_extended_profile': False,
#   'id': 2437781952,
#   'id_str': '2437781952',
#   'is_translation_enabled': False,
#   'is_translator': False,
#   'lang': 'es',
#   'listed_count': 0,
#   'location': '',
#   'name': 'Maria Jose Núñez ',
#   'notifications': False,
#   'profile_background_color': 'C0DEED',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_tile': False,
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2437781952/1400199838',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/467097968756011009/4IweMKYJ_normal.jpeg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/467097968756011009/4IweMKYJ_normal.jpeg',
#   'profile_link_color': '1DA1F2',
#   'profile_sidebar_border_color': 'C0DEED',
#   'profile_sidebar_fill_color': 'DDEEF6',
#   'profile_text_color': '333333',
#   'profile_use_background_image': True,
#   'protected': False,
#   'screen_name': 'mjnunezruiz',
#   'statuses_count': 33,
#   'time_zone': 'Santiago',
#   'translator_type': 'none',
#   'url': None,
#   'utc_offset': -10800,
#   'verified': False}}

# %% [markdown]
# ## 2. Consultar la API de Twitter

# %% [markdown]
# - Utilizando una librería Python que permite enviar consultas HTTP a la API de Twitter, conectarse a un 'endpoint' de la API para leer datos. Ver la lista de los endpoints: https://developer.twitter.com/en/docs/tweets/post-and-engage/overview

# %%
twitter.search(q='Valdivia')
twitter.search(q='Valdivia', result_type='popular')
# Out:
# {'search_metadata': {'completed_in': 0.028,
#   'count': 15,
#   'max_id': 0,
#   'max_id_str': '0',
#   'next_results': '?max_id=978313924469813247&q=Valdivia&include_entities=1&result_type=popular',
#   'query': 'Valdivia',
#   'since_id': 0,
#   'since_id_str': '0'},
#  'statuses': [{'contributors': None,
#    'coordinates': None,
#    'created_at': 'Tue Apr 03 18:13:31 +0000 2018',
#    'entities': {'hashtags': [],
#     'media': [{'display_url': 'pic.twitter.com/xIP5jxDRbh',
#       'expanded_url': 'https://twitter.com/biobio/status/981233248096473091/photo/1',
#       'id': 981233237736407040,
#       'id_str': '981233237736407040',
#       'indices': [108, 131],
#       'media_url': 'http://pbs.twimg.com/media/DZ4KblEVwAAd2s5.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/DZ4KblEVwAAd2s5.jpg',
#       'sizes': {'large': {'h': 408, 'resize': 'fit', 'w': 640},
#        'medium': {'h': 408, 'resize': 'fit', 'w': 640},
#        'small': {'h': 408, 'resize': 'fit', 'w': 640},
#        'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#       'type': 'photo',
#       'url': 'https://t.co/xIP5jxDRbh'}],
#     'symbols': [],
#     'urls': [{'display_url': 'rbb.cl/jsmj',
#       'expanded_url': 'http://rbb.cl/jsmj',
#       'indices': [84, 107],
#       'url': 'https://t.co/XBEyh6f2oQ'}],
#     'user_mentions': []},
#    'extended_entities': {'media': [{'display_url': 'pic.twitter.com/xIP5jxDRbh',
#       'expanded_url': 'https://twitter.com/biobio/status/981233248096473091/photo/1',
#       'id': 981233237736407040,
#       'id_str': '981233237736407040',
#       'indices': [108, 131],
#       'media_url': 'http://pbs.twimg.com/media/DZ4KblEVwAAd2s5.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/DZ4KblEVwAAd2s5.jpg',
#       'sizes': {'large': {'h': 408, 'resize': 'fit', 'w': 640},
#        'medium': {'h': 408, 'resize': 'fit', 'w': 640},
#        'small': {'h': 408, 'resize': 'fit', 'w': 640},
#        'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#       'type': 'photo',
#       'url': 'https://t.co/xIP5jxDRbh'}]},
#    'favorite_count': 13,
#    'favorited': False,
#    'geo': None,
#    'id': 981233248096473091,
#    'id_str': '981233248096473091',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'es',
#    'metadata': {'iso_language_code': 'es', 'result_type': 'popular'},
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 40,
#    'retweeted': False,
#    'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#    'text': 'Actividades mineras en el río Valdivia afectarían hábitat de cisnes de cuello negro https://t.co/XBEyh6f2oQ https://t.co/xIP5jxDRbh',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Sat May 03 15:15:06 +0000 2008',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': 'Cuéntanos todo lo que ocurre en tu ciudad  📲 ¿Tienes un video que quieras compartir? Envíalo al +56 9 8149 2444',
#     'entities': {'description': {'urls': []},
#      'url': {'urls': [{'display_url': 'biobiochile.cl',
#         'expanded_url': 'http://www.biobiochile.cl',
#         'indices': [0, 23],
#         'url': 'https://t.co/bwzwESePWa'}]}},
#     'favourites_count': 12295,
#     'follow_request_sent': False,
#     'followers_count': 2790146,
#     'following': True,
#     'friends_count': 16915,
#     'geo_enabled': True,
#     'has_extended_profile': True,
#     'id': 14638581,
#     'id_str': '14638581',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'es',
#     'listed_count': 10622,
#     'location': 'Chile',
#     'name': 'BioBioChile',
#     'notifications': False,
#     'profile_background_color': 'FFFFFF',
#     'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/378800000030294310/0d8b3c7001dc4de55d2a3d3f905707d3.png',
#     'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/378800000030294310/0d8b3c7001dc4de55d2a3d3f905707d3.png',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/14638581/1522665919',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/905753852552601602/9TN4W1_M_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/905753852552601602/9TN4W1_M_normal.jpg',
#     'profile_link_color': '029BB3',
#     'profile_sidebar_border_color': 'FFFFFF',
#     'profile_sidebar_fill_color': 'B5D7F2',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'biobio',
#     'statuses_count': 681296,
#     'time_zone': 'Santiago',
#     'translator_type': 'none',
#     'url': 'https://t.co/bwzwESePWa',
#     'utc_offset': -10800,
#     'verified': True}},
#   {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Tue Apr 03 13:20:26 +0000 2018',
#    'entities': {'hashtags': [{'indices': [0, 7], 'text': 'Osorno'},
#      {'indices': [45, 51], 'text': 'Chile'}],
#     'symbols': [],
#     'urls': [{'display_url': 'twitter.com/i/web/status/9…',
#       'expanded_url': 'https://twitter.com/i/web/status/981159492942422016',
#       'indices': [117, 140],
#       'url': 'https://t.co/6SGOWfVvVM'}],
#     'user_mentions': []},
#    'favorite_count': 71,
#    'favorited': False,
#    'geo': None,
#    'id': 981159492942422016,
#    'id_str': '981159492942422016',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'es',
#    'metadata': {'iso_language_code': 'es', 'result_type': 'popular'},
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 36,
#    'retweeted': False,
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'text': '#Osorno será el primer lugar que visitaré en #Chile en mayo. Os espero allí el día 10 de ese mes, para comenzar est… https://t.co/6SGOWfVvVM',
#    'truncated': True,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Tue Apr 28 00:21:03 +0000 2009',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': 'Bienvenidos a la cuenta oficial de ALEX UBAGO en Twitter. Facebook: Alex Ubago Music. Instagram: alexubagoficial. Booking: Get In (+34) 943 316911',
#     'entities': {'description': {'urls': []},
#      'url': {'urls': [{'display_url': 'alexubago.com',
#         'expanded_url': 'http://www.alexubago.com',
#         'indices': [0, 23],
#         'url': 'https://t.co/MhVTTuCdaf'}]}},
#     'favourites_count': 3352,
#     'follow_request_sent': False,
#     'followers_count': 435230,
#     'following': False,
#     'friends_count': 621,
#     'geo_enabled': False,
#     'has_extended_profile': False,
#     'id': 35920356,
#     'id_str': '35920356',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 976,
#     'location': 'España',
#     'name': 'Alex Ubago Oficial',
#     'notifications': False,
#     'profile_background_color': 'C6E2EE',
#     'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/656810638/e8dnwprajv2zwwk3p2kt.jpeg',
#     'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/656810638/e8dnwprajv2zwwk3p2kt.jpeg',
#     'profile_background_tile': True,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/35920356/1518455774',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/860512692641177602/WF-yygoV_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/860512692641177602/WF-yygoV_normal.jpg',
#     'profile_link_color': '1F98C7',
#     'profile_sidebar_border_color': 'C6E2EE',
#     'profile_sidebar_fill_color': 'DAECF4',
#     'profile_text_color': '663B12',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'AlexUbagoficial',
#     'statuses_count': 10012,
#     'time_zone': 'Pacific Time (US & Canada)',
#     'translator_type': 'none',
#     'url': 'https://t.co/MhVTTuCdaf',
#     'utc_offset': -25200,
#     'verified': True}},
#   {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Mon Apr 02 15:38:49 +0000 2018',
#    'entities': {'hashtags': [],
#     'media': [{'display_url': 'pic.twitter.com/kVc42byt8p',
#       'expanded_url': 'https://twitter.com/SaoPauloFC/status/980831930668257280/photo/1',
#       'id': 980831920060760064,
#       'id_str': '980831920060760064',
#       'indices': [88, 111],
#       'media_url': 'http://pbs.twimg.com/media/DZydb0OWAAAJc4O.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/DZydb0OWAAAJc4O.jpg',
#       'sizes': {'large': {'h': 515, 'resize': 'fit', 'w': 800},
#        'medium': {'h': 515, 'resize': 'fit', 'w': 800},
#        'small': {'h': 438, 'resize': 'fit', 'w': 680},
#        'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#       'type': 'photo',
#       'url': 'https://t.co/kVc42byt8p'}],
#     'symbols': [],
#     'urls': [{'display_url': 'spfc.vc/2H6h9mE',
#       'expanded_url': 'https://spfc.vc/2H6h9mE',
#       'indices': [64, 87],
#       'url': 'https://t.co/bVRc8i2YWk'}],
#     'user_mentions': []},
#    'extended_entities': {'media': [{'display_url': 'pic.twitter.com/kVc42byt8p',
#       'expanded_url': 'https://twitter.com/SaoPauloFC/status/980831930668257280/photo/1',
#       'id': 980831920060760064,
#       'id_str': '980831920060760064',
#       'indices': [88, 111],
#       'media_url': 'http://pbs.twimg.com/media/DZydb0OWAAAJc4O.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/DZydb0OWAAAJc4O.jpg',
#       'sizes': {'large': {'h': 515, 'resize': 'fit', 'w': 800},
#        'medium': {'h': 515, 'resize': 'fit', 'w': 800},
#        'small': {'h': 438, 'resize': 'fit', 'w': 680},
#        'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#       'type': 'photo',
#       'url': 'https://t.co/kVc42byt8p'}]},
#    'favorite_count': 1048,
#    'favorited': False,
#    'geo': None,
#    'id': 980831930668257280,
#    'id_str': '980831930668257280',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'pt',
#    'metadata': {'iso_language_code': 'pt', 'result_type': 'popular'},
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 121,
#    'retweeted': False,
#    'source': '<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>',
#    'text': 'Valdívia inicia nova etapa na recuperação e trabalha no campo \n\nhttps://t.co/bVRc8i2YWk https://t.co/kVc42byt8p',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Tue Mar 17 17:50:28 +0000 2009',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': 'Twitter oficial do Tricolor | EN: @SaoPauloFC_eng | ES: @SaoPauloFC_esp | snap: saopaulofc1930',
#     'entities': {'description': {'urls': []},
#      'url': {'urls': [{'display_url': 'saopaulofc.net',
#         'expanded_url': 'http://saopaulofc.net',
#         'indices': [0, 23],
#         'url': 'https://t.co/ufpxO1TTvJ'}]}},
#     'favourites_count': 2301,
#     'follow_request_sent': False,
#     'followers_count': 4190111,
#     'following': False,
#     'friends_count': 55,
#     'geo_enabled': False,
#     'has_extended_profile': True,
#     'id': 24920669,
#     'id_str': '24920669',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'pt',
#     'listed_count': 5702,
#     'location': 'São Paulo',
#     'name': 'São Paulo FC',
#     'notifications': False,
#     'profile_background_color': 'DB1000',
#     'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/336345315/SPFC_youtube.jpg',
#     'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/336345315/SPFC_youtube.jpg',
#     'profile_background_tile': True,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/24920669/1501086322',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/890246604858556417/DYaXelhi_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/890246604858556417/DYaXelhi_normal.jpg',
#     'profile_link_color': 'D71920',
#     'profile_sidebar_border_color': 'FFFFFF',
#     'profile_sidebar_fill_color': 'E6E6E6',
#     'profile_text_color': '525252',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'SaoPauloFC',
#     'statuses_count': 53557,
#     'time_zone': 'Brasilia',
#     'translator_type': 'none',
#     'url': 'https://t.co/ufpxO1TTvJ',
#     'utc_offset': -10800,
#     'verified': True}},
#   {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Mon Apr 02 21:59:53 +0000 2018',
#    'entities': {'hashtags': [],
#     'media': [{'display_url': 'pic.twitter.com/hmPTMeNFSD',
#       'expanded_url': 'https://twitter.com/biobio/status/980927828601417729/photo/1',
#       'id': 980927803175575552,
#       'id_str': '980927803175575552',
#       'indices': [114, 137],
#       'media_url': 'http://pbs.twimg.com/media/DZz0o8qVoAAH1mO.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/DZz0o8qVoAAH1mO.jpg',
#       'sizes': {'large': {'h': 585, 'resize': 'fit', 'w': 1040},
#        'medium': {'h': 585, 'resize': 'fit', 'w': 1040},
#        'small': {'h': 383, 'resize': 'fit', 'w': 680},
#        'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#       'type': 'photo',
#       'url': 'https://t.co/hmPTMeNFSD'}],
#     'symbols': [],
#     'urls': [{'display_url': 'rbb.cl/jsad',
#       'expanded_url': 'http://rbb.cl/jsad',
#       'indices': [90, 113],
#       'url': 'https://t.co/gNSoALPfx9'}],
#     'user_mentions': []},
#    'extended_entities': {'media': [{'display_url': 'pic.twitter.com/hmPTMeNFSD',
#       'expanded_url': 'https://twitter.com/biobio/status/980927828601417729/photo/1',
#       'id': 980927803175575552,
#       'id_str': '980927803175575552',
#       'indices': [114, 137],
#       'media_url': 'http://pbs.twimg.com/media/DZz0o8qVoAAH1mO.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/DZz0o8qVoAAH1mO.jpg',
#       'sizes': {'large': {'h': 585, 'resize': 'fit', 'w': 1040},
#        'medium': {'h': 585, 'resize': 'fit', 'w': 1040},
#        'small': {'h': 383, 'resize': 'fit', 'w': 680},
#        'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#       'type': 'photo',
#       'url': 'https://t.co/hmPTMeNFSD'}]},
#    'favorite_count': 26,
#    'favorited': False,
#    'geo': None,
#    'id': 980927828601417729,
#    'id_str': '980927828601417729',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'es',
#    'metadata': {'iso_language_code': 'es', 'result_type': 'popular'},
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 19,
#    'retweeted': False,
#    'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#    'text': 'Sernageomin ordena paralizar obras de concesión minera en Río Valdivia y borde de humedal https://t.co/gNSoALPfx9 https://t.co/hmPTMeNFSD',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Sat May 03 15:15:06 +0000 2008',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': 'Cuéntanos todo lo que ocurre en tu ciudad  📲 ¿Tienes un video que quieras compartir? Envíalo al +56 9 8149 2444',
#     'entities': {'description': {'urls': []},
#      'url': {'urls': [{'display_url': 'biobiochile.cl',
#         'expanded_url': 'http://www.biobiochile.cl',
#         'indices': [0, 23],
#         'url': 'https://t.co/bwzwESePWa'}]}},
#     'favourites_count': 12295,
#     'follow_request_sent': False,
#     'followers_count': 2790146,
#     'following': True,
#     'friends_count': 16915,
#     'geo_enabled': True,
#     'has_extended_profile': True,
#     'id': 14638581,
#     'id_str': '14638581',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'es',
#     'listed_count': 10622,
#     'location': 'Chile',
#     'name': 'BioBioChile',
#     'notifications': False,
#     'profile_background_color': 'FFFFFF',
#     'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/378800000030294310/0d8b3c7001dc4de55d2a3d3f905707d3.png',
#     'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/378800000030294310/0d8b3c7001dc4de55d2a3d3f905707d3.png',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/14638581/1522665919',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/905753852552601602/9TN4W1_M_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/905753852552601602/9TN4W1_M_normal.jpg',
#     'profile_link_color': '029BB3',
#     'profile_sidebar_border_color': 'FFFFFF',
#     'profile_sidebar_fill_color': 'B5D7F2',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'biobio',
#     'statuses_count': 681296,
#     'time_zone': 'Santiago',
#     'translator_type': 'none',
#     'url': 'https://t.co/bwzwESePWa',
#     'utc_offset': -10800,
#     'verified': True}},
#   {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Wed Apr 04 02:19:10 +0000 2018',
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'urls': [{'display_url': 'twitter.com/i/web/status/9…',
#       'expanded_url': 'https://twitter.com/i/web/status/981355465874472960',
#       'indices': [117, 140],
#       'url': 'https://t.co/r7wAHWjmpQ'}],
#     'user_mentions': []},
#    'favorite_count': 22,
#    'favorited': False,
#    'geo': None,
#    'id': 981355465874472960,
#    'id_str': '981355465874472960',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'es',
#    'metadata': {'iso_language_code': 'es', 'result_type': 'popular'},
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 18,
#    'retweeted': False,
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'text': 'Hoy en el municipio de Valdivia firmamos el inicio de las obras de rehabilitación y pavimentación de la vía veredal… https://t.co/r7wAHWjmpQ',
#    'truncated': True,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Mon Sep 13 17:55:35 +0000 2010',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': 'Gobernador de Antioquia #PiensaEnGrande',
#     'entities': {'description': {'urls': []},
#      'url': {'urls': [{'display_url': 'antioquia.gov.co',
#         'expanded_url': 'http://www.antioquia.gov.co',
#         'indices': [0, 23],
#         'url': 'https://t.co/B7taICKM0V'}]}},
#     'favourites_count': 11688,
#     'follow_request_sent': False,
#     'followers_count': 48176,
#     'following': False,
#     'friends_count': 1101,
#     'geo_enabled': True,
#     'has_extended_profile': True,
#     'id': 190334558,
#     'id_str': '190334558',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'es',
#     'listed_count': 253,
#     'location': 'Medellín, Antioquia',
#     'name': 'Luis Pérez Gutiérrez',
#     'notifications': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/632191109104541696/XIuPuSI4.jpg',
#     'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/632191109104541696/XIuPuSI4.jpg',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/190334558/1521661024',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/776593180498231296/5Y3H9mHt_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/776593180498231296/5Y3H9mHt_normal.jpg',
#     'profile_link_color': '0084B4',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'Luis_Perez_G',
#     'statuses_count': 17173,
#     'time_zone': 'Bogota',
#     'translator_type': 'none',
#     'url': 'https://t.co/B7taICKM0V',
#     'utc_offset': -18000,
#     'verified': True}},
#   {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Tue Apr 03 20:28:03 +0000 2018',
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'urls': [{'display_url': 'twitter.com/i/web/status/9…',
#       'expanded_url': 'https://twitter.com/i/web/status/981267103033577474',
#       'indices': [117, 140],
#       'url': 'https://t.co/JNwnEjVXgx'}],
#     'user_mentions': [{'id': 2434104564,
#       'id_str': '2434104564',
#       'indices': [25, 37],
#       'name': 'PAZ CIUDADANA',
#       'screen_name': 'FPCIUDADANA'},
#      {'id': 34658505,
#       'id_str': '34658505',
#       'indices': [78, 85],
#       'name': 'Movilh Chile',
#       'screen_name': 'Movilh'}]},
#    'favorite_count': 14,
#    'favorited': False,
#    'geo': None,
#    'id': 981267103033577474,
#    'id_str': '981267103033577474',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'es',
#    'metadata': {'iso_language_code': 'es', 'result_type': 'popular'},
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 10,
#    'retweeted': False,
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'text': 'Las reuniones de hoy con @FPCIUDADANA, Cámara Chilena de Centros Comerciales, @Movilh y el Alcalde de Valdivia, rea… https://t.co/JNwnEjVXgx',
#    'truncated': True,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Thu Sep 15 19:07:52 +0000 2011',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': 'Cuenta oficial de la Subsecretaría de Prevención del Delito. Ministerio del Interior y Seguridad Pública.',
#     'entities': {'description': {'urls': []},
#      'url': {'urls': [{'display_url': 'seguridadpublica.gov.cl',
#         'expanded_url': 'http://www.seguridadpublica.gov.cl/',
#         'indices': [0, 23],
#         'url': 'https://t.co/ZE6inYxOB5'}]}},
#     'favourites_count': 395,
#     'follow_request_sent': False,
#     'followers_count': 18884,
#     'following': False,
#     'friends_count': 3157,
#     'geo_enabled': True,
#     'has_extended_profile': False,
#     'id': 374124320,
#     'id_str': '374124320',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'es',
#     'listed_count': 92,
#     'location': 'Chile',
#     'name': 'S. Prevención Delito',
#     'notifications': False,
#     'profile_background_color': 'ABB8C2',
#     'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/445597226266423296/yt--g57N.jpeg',
#     'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/445597226266423296/yt--g57N.jpeg',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/374124320/1522267327',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/973587221419831296/VyOooM9M_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/973587221419831296/VyOooM9M_normal.jpg',
#     'profile_link_color': 'ABB8C2',
#     'profile_sidebar_border_color': 'FFFFFF',
#     'profile_sidebar_fill_color': 'AEBDBD',
#     'profile_text_color': '3E3B42',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'SubPrevDelito',
#     'statuses_count': 14428,
#     'time_zone': 'Santiago',
#     'translator_type': 'none',
#     'url': 'https://t.co/ZE6inYxOB5',
#     'utc_offset': -10800,
#     'verified': True}},
#   {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Wed Apr 04 03:43:41 +0000 2018',
#    'entities': {'hashtags': [],
#     'media': [{'display_url': 'pic.twitter.com/6YaRvvyb3W',
#       'expanded_url': 'https://twitter.com/biobio/status/981376736607854592/photo/1',
#       'id': 981375759079104512,
#       'id_str': '981375759079104512',
#       'indices': [108, 131],
#       'media_url': 'http://pbs.twimg.com/media/DZ6MDacW4AAVtZq.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/DZ6MDacW4AAVtZq.jpg',
#       'sizes': {'large': {'h': 563, 'resize': 'fit', 'w': 900},
#        'medium': {'h': 563, 'resize': 'fit', 'w': 900},
#        'small': {'h': 425, 'resize': 'fit', 'w': 680},
#        'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#       'type': 'photo',
#       'url': 'https://t.co/6YaRvvyb3W'}],
#     'symbols': [],
#     'urls': [{'display_url': 'rbb.cl/jsu4',
#       'expanded_url': 'http://rbb.cl/jsu4',
#       'indices': [84, 107],
#       'url': 'https://t.co/PqfuRRvgSl'}],
#     'user_mentions': []},
#    'extended_entities': {'media': [{'display_url': 'pic.twitter.com/6YaRvvyb3W',
#       'expanded_url': 'https://twitter.com/biobio/status/981376736607854592/photo/1',
#       'id': 981375759079104512,
#       'id_str': '981375759079104512',
#       'indices': [108, 131],
#       'media_url': 'http://pbs.twimg.com/media/DZ6MDacW4AAVtZq.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/DZ6MDacW4AAVtZq.jpg',
#       'sizes': {'large': {'h': 563, 'resize': 'fit', 'w': 900},
#        'medium': {'h': 563, 'resize': 'fit', 'w': 900},
#        'small': {'h': 425, 'resize': 'fit', 'w': 680},
#        'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#       'type': 'photo',
#       'url': 'https://t.co/6YaRvvyb3W'}]},
#    'favorite_count': 5,
#    'favorited': False,
#    'geo': None,
#    'id': 981376736607854592,
#    'id_str': '981376736607854592',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'es',
#    'metadata': {'iso_language_code': 'es', 'result_type': 'popular'},
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 4,
#    'retweeted': False,
#    'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#    'text': 'Municipio de Valdivia dispuso de $130 millones para arreglar calles mediante bacheo https://t.co/PqfuRRvgSl https://t.co/6YaRvvyb3W',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Sat May 03 15:15:06 +0000 2008',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': 'Cuéntanos todo lo que ocurre en tu ciudad  📲 ¿Tienes un video que quieras compartir? Envíalo al +56 9 8149 2444',
#     'entities': {'description': {'urls': []},
#      'url': {'urls': [{'display_url': 'biobiochile.cl',
#         'expanded_url': 'http://www.biobiochile.cl',
#         'indices': [0, 23],
#         'url': 'https://t.co/bwzwESePWa'}]}},
#     'favourites_count': 12295,
#     'follow_request_sent': False,
#     'followers_count': 2790146,
#     'following': True,
#     'friends_count': 16915,
#     'geo_enabled': True,
#     'has_extended_profile': True,
#     'id': 14638581,
#     'id_str': '14638581',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'es',
#     'listed_count': 10622,
#     'location': 'Chile',
#     'name': 'BioBioChile',
#     'notifications': False,
#     'profile_background_color': 'FFFFFF',
#     'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/378800000030294310/0d8b3c7001dc4de55d2a3d3f905707d3.png',
#     'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/378800000030294310/0d8b3c7001dc4de55d2a3d3f905707d3.png',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/14638581/1522665919',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/905753852552601602/9TN4W1_M_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/905753852552601602/9TN4W1_M_normal.jpg',
#     'profile_link_color': '029BB3',
#     'profile_sidebar_border_color': 'FFFFFF',
#     'profile_sidebar_fill_color': 'B5D7F2',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'biobio',
#     'statuses_count': 681296,
#     'time_zone': 'Santiago',
#     'translator_type': 'none',
#     'url': 'https://t.co/bwzwESePWa',
#     'utc_offset': -10800,
#     'verified': True}},
#   {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Fri Mar 30 15:02:28 +0000 2018',
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'urls': [{'display_url': 'twitter.com/i/web/status/9…',
#       'expanded_url': 'https://twitter.com/i/web/status/979735618551992322',
#       'indices': [117, 140],
#       'url': 'https://t.co/pVXDCzhxCI'}],
#     'user_mentions': []},
#    'favorite_count': 716,
#    'favorited': False,
#    'geo': None,
#    'id': 979735618551992322,
#    'id_str': '979735618551992322',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'pt',
#    'metadata': {'iso_language_code': 'pt', 'result_type': 'popular'},
#    'place': None,
#    'retweet_count': 80,
#    'retweeted': False,
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'text': 'Informação: Valdivia não joga contra o Ateltico Paranaense, quarta, pela copa do Brasil. Jogador segue no DM tratan… https://t.co/pVXDCzhxCI',
#    'truncated': True,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Wed Jan 21 12:10:43 +0000 2009',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': 'Jornalista, repórter do Grupo Globo, apaixonado por esportes e fuçador do mundo afora. Pai da Nina e do Bento. Também estou lá no https://t.co/BuCkWB73aR',
#     'entities': {'description': {'urls': [{'display_url': 'bit.ly/2asZU3c',
#         'expanded_url': 'http://bit.ly/2asZU3c',
#         'indices': [130, 153],
#         'url': 'https://t.co/BuCkWB73aR'}]},
#      'url': {'urls': [{'display_url': 'globoespote.com',
#         'expanded_url': 'http://globoespote.com',
#         'indices': [0, 23],
#         'url': 'https://t.co/YGsTOlXrWX'}]}},
#     'favourites_count': 3777,
#     'follow_request_sent': False,
#     'followers_count': 87909,
#     'following': False,
#     'friends_count': 1548,
#     'geo_enabled': True,
#     'has_extended_profile': True,
#     'id': 19285159,
#     'id_str': '19285159',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'pt',
#     'listed_count': 328,
#     'location': 'santiago, chile',
#     'name': 'André Hernan',
#     'notifications': False,
#     'profile_background_color': 'F3AA2B',
#     'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/3995914/foto3.jpg',
#     'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/3995914/foto3.jpg',
#     'profile_background_tile': True,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/910451804265226240/bEkoqg-e_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/910451804265226240/bEkoqg-e_normal.jpg',
#     'profile_link_color': '0890B4',
#     'profile_sidebar_border_color': '0D0C0C',
#     'profile_sidebar_fill_color': 'F5A429',
#     'profile_text_color': '00050A',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'andrehernan',
#     'statuses_count': 26819,
#     'time_zone': 'Greenland',
#     'translator_type': 'none',
#     'url': 'https://t.co/YGsTOlXrWX',
#     'utc_offset': -7200,
#     'verified': True}},
#   {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Sat Mar 31 14:00:02 +0000 2018',
#    'entities': {'hashtags': [{'indices': [26, 42], 'text': 'CentralFOXChile'}],
#     'symbols': [],
#     'urls': [{'display_url': 'twitter.com/i/web/status/9…',
#       'expanded_url': 'https://twitter.com/i/web/status/980082293657219072',
#       'indices': [117, 140],
#       'url': 'https://t.co/BbyCz2WnV3'}],
#     'user_mentions': [{'id': 274805972,
#       'id_str': '274805972',
#       'indices': [43, 59],
#       'name': 'Jorge Valdivia',
#       'screen_name': 'el_mago_oficial'},
#      {'id': 350862837,
#       'id_str': '350862837',
#       'indices': [62, 74],
#       'name': 'Diego Buonanotte',
#       'screen_name': 'Diego_Buona'}]},
#    'favorite_count': 60,
#    'favorited': False,
#    'geo': None,
#    'id': 980082293657219072,
#    'id_str': '980082293657219072',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'es',
#    'metadata': {'iso_language_code': 'es', 'result_type': 'popular'},
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 53,
#    'retweeted': False,
#    'source': '<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>',
#    'text': '¿EL "MAGO" O EL "ENANO"?\n\n#CentralFOXChile @el_mago_oficial y @Diego_Buona se verán las caras en este nuevo Clásico… https://t.co/BbyCz2WnV3',
#    'truncated': True,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Thu Jul 25 15:46:21 +0000 2013',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': 'Twitter oficial de FOX Sports Chile. El canal de deportes #1 en audiencia en Latinoamérica.',
#     'entities': {'description': {'urls': []},
#      'url': {'urls': [{'display_url': 'foxsportsla.com',
#         'expanded_url': 'http://www.foxsportsla.com',
#         'indices': [0, 23],
#         'url': 'https://t.co/JNVCGJFIrY'}]}},
#     'favourites_count': 3633,
#     'follow_request_sent': False,
#     'followers_count': 191559,
#     'following': False,
#     'friends_count': 59,
#     'geo_enabled': False,
#     'has_extended_profile': False,
#     'id': 1620648822,
#     'id_str': '1620648822',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'es',
#     'listed_count': 350,
#     'location': 'Chile',
#     'name': 'FOX Sports Chile',
#     'notifications': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/596318340966055936/frS7roCd.jpg',
#     'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/596318340966055936/frS7roCd.jpg',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1620648822/1520094839',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/918562478178660355/FzYReq74_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/918562478178660355/FzYReq74_normal.jpg',
#     'profile_link_color': '0084B4',
#     'profile_sidebar_border_color': 'FFFFFF',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': False,
#     'protected': False,
#     'screen_name': 'FOXSports_Chile',
#     'statuses_count': 63487,
#     'time_zone': 'Santiago',
#     'translator_type': 'none',
#     'url': 'https://t.co/JNVCGJFIrY',
#     'utc_offset': -10800,
#     'verified': True}},
#   {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Sun Apr 01 14:14:41 +0000 2018',
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'urls': [{'display_url': 'twitter.com/i/web/status/9…',
#       'expanded_url': 'https://twitter.com/i/web/status/980448366638325760',
#       'indices': [116, 139],
#       'url': 'https://t.co/92cKkk7Sy0'}],
#     'user_mentions': []},
#    'favorite_count': 38,
#    'favorited': False,
#    'geo': None,
#    'id': 980448366638325760,
#    'id_str': '980448366638325760',
#    'in_reply_to_screen_name': 'AlfredoRamosM',
#    'in_reply_to_status_id': 980447885107126272,
#    'in_reply_to_status_id_str': '980447885107126272',
#    'in_reply_to_user_id': 50494032,
#    'in_reply_to_user_id_str': '50494032',
#    'is_quote_status': False,
#    'lang': 'es',
#    'metadata': {'iso_language_code': 'es', 'result_type': 'popular'},
#    'place': None,
#    'retweet_count': 48,
#    'retweeted': False,
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'text': 'De los 400 kilómetros más caros del mundo en peajes, sólo existe alrededor de 15 kms en doble calzada. Y existen 2… https://t.co/92cKkk7Sy0',
#    'truncated': True,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Thu Jun 25 00:25:55 +0000 2009',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': 'Defensor de la propiedad privada y la libertad individual, del emprendimiento, la ciencia y la transparencia',
#     'entities': {'description': {'urls': []},
#      'url': {'urls': [{'display_url': 'facebook.com/AlfredoRamosMa…',
#         'expanded_url': 'http://facebook.com/AlfredoRamosMayaOficial',
#         'indices': [0, 23],
#         'url': 'https://t.co/TcyuDzwtPo'}]}},
#     'favourites_count': 6173,
#     'follow_request_sent': False,
#     'followers_count': 142326,
#     'following': False,
#     'friends_count': 1266,
#     'geo_enabled': True,
#     'has_extended_profile': False,
#     'id': 50494032,
#     'id_str': '50494032',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 190,
#     'location': 'Medellín, Colombia',
#     'name': 'Alfredo Ramos Maya',
#     'notifications': False,
#     'profile_background_color': '086B0B',
#     'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/378800000120758845/10096c784242438657b54451093f8d38.jpeg',
#     'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/378800000120758845/10096c784242438657b54451093f8d38.jpeg',
#     'profile_background_tile': True,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/50494032/1492457816',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/967867442331635712/8Ecu8ZSV_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/967867442331635712/8Ecu8ZSV_normal.jpg',
#     'profile_link_color': 'A7A9DB',
#     'profile_sidebar_border_color': 'FFFFFF',
#     'profile_sidebar_fill_color': '086B0B',
#     'profile_text_color': 'A7A9DB',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'AlfredoRamosM',
#     'statuses_count': 9658,
#     'time_zone': 'Bogota',
#     'translator_type': 'none',
#     'url': 'https://t.co/TcyuDzwtPo',
#     'utc_offset': -18000,
#     'verified': True}},
#   {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Thu Mar 29 19:04:06 +0000 2018',
#    'entities': {'hashtags': [{'indices': [34, 46], 'text': 'SemanaSanta'},
#      {'indices': [72, 81], 'text': 'Valdivia'}],
#     'media': [{'display_url': 'pic.twitter.com/LhUYMpIzjZ',
#       'expanded_url': 'https://twitter.com/Ejercito_Chile/status/979434038279725056/photo/1',
#       'id': 979434019141177345,
#       'id_str': '979434019141177345',
#       'indices': [82, 105],
#       'media_url': 'http://pbs.twimg.com/media/DZemDRfX0AEJlcy.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/DZemDRfX0AEJlcy.jpg',
#       'sizes': {'large': {'h': 428, 'resize': 'fit', 'w': 1024},
#        'medium': {'h': 428, 'resize': 'fit', 'w': 1024},
#        'small': {'h': 284, 'resize': 'fit', 'w': 680},
#        'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#       'type': 'photo',
#       'url': 'https://t.co/LhUYMpIzjZ'}],
#     'symbols': [],
#     'urls': [],
#     'user_mentions': []},
#    'extended_entities': {'media': [{'display_url': 'pic.twitter.com/LhUYMpIzjZ',
#       'expanded_url': 'https://twitter.com/Ejercito_Chile/status/979434038279725056/photo/1',
#       'id': 979434019141177345,
#       'id_str': '979434019141177345',
#       'indices': [82, 105],
#       'media_url': 'http://pbs.twimg.com/media/DZemDRfX0AEJlcy.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/DZemDRfX0AEJlcy.jpg',
#       'sizes': {'large': {'h': 428, 'resize': 'fit', 'w': 1024},
#        'medium': {'h': 428, 'resize': 'fit', 'w': 1024},
#        'small': {'h': 284, 'resize': 'fit', 'w': 680},
#        'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#       'type': 'photo',
#       'url': 'https://t.co/LhUYMpIzjZ'},
#      {'display_url': 'pic.twitter.com/LhUYMpIzjZ',
#       'expanded_url': 'https://twitter.com/Ejercito_Chile/status/979434038279725056/photo/1',
#       'id': 979434019984171008,
#       'id_str': '979434019984171008',
#       'indices': [82, 105],
#       'media_url': 'http://pbs.twimg.com/media/DZemDUoW4AAq-Ej.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/DZemDUoW4AAq-Ej.jpg',
#       'sizes': {'large': {'h': 768, 'resize': 'fit', 'w': 1024},
#        'medium': {'h': 768, 'resize': 'fit', 'w': 1024},
#        'small': {'h': 510, 'resize': 'fit', 'w': 680},
#        'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#       'type': 'photo',
#       'url': 'https://t.co/LhUYMpIzjZ'},
#      {'display_url': 'pic.twitter.com/LhUYMpIzjZ',
#       'expanded_url': 'https://twitter.com/Ejercito_Chile/status/979434038279725056/photo/1',
#       'id': 979434020000993280,
#       'id_str': '979434020000993280',
#       'indices': [82, 105],
#       'media_url': 'http://pbs.twimg.com/media/DZemDUsXkAAYtKO.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/DZemDUsXkAAYtKO.jpg',
#       'sizes': {'large': {'h': 442, 'resize': 'fit', 'w': 1024},
#        'medium': {'h': 442, 'resize': 'fit', 'w': 1024},
#        'small': {'h': 294, 'resize': 'fit', 'w': 680},
#        'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#       'type': 'photo',
#       'url': 'https://t.co/LhUYMpIzjZ'}]},
#    'favorite_count': 48,
#    'favorited': False,
#    'geo': None,
#    'id': 979434038279725056,
#    'id_str': '979434038279725056',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'es',
#    'metadata': {'iso_language_code': 'es', 'result_type': 'popular'},
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 17,
#    'retweeted': False,
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'text': 'Liturgia de oración con motivo de #SemanaSanta 2018 en el Campo Militar #Valdivia https://t.co/LhUYMpIzjZ',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Fri Jan 15 17:10:40 +0000 2010',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': 'Bienvenidos a la cuenta oficial del Ejército de Chile.',
#     'entities': {'description': {'urls': []},
#      'url': {'urls': [{'display_url': 'ejercito.cl',
#         'expanded_url': 'http://www.ejercito.cl',
#         'indices': [0, 22],
#         'url': 'http://t.co/6IO6yIL6lA'}]}},
#     'favourites_count': 882,
#     'follow_request_sent': False,
#     'followers_count': 187020,
#     'following': False,
#     'friends_count': 75,
#     'geo_enabled': True,
#     'has_extended_profile': False,
#     'id': 105197626,
#     'id_str': '105197626',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'es',
#     'listed_count': 778,
#     'location': 'Avenida Tupper 1725, CL',
#     'name': 'Ejército de Chile',
#     'notifications': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/635709399/3khyh1ss0vh3cbm5kxfg.jpeg',
#     'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/635709399/3khyh1ss0vh3cbm5kxfg.jpeg',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/105197626/1498580542',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/899256174821945344/QydQFA_4_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/899256174821945344/QydQFA_4_normal.jpg',
#     'profile_link_color': 'B50000',
#     'profile_sidebar_border_color': 'FFFFFF',
#     'profile_sidebar_fill_color': 'F5E1C4',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'Ejercito_Chile',
#     'statuses_count': 7620,
#     'time_zone': 'Santiago',
#     'translator_type': 'none',
#     'url': 'http://t.co/6IO6yIL6lA',
#     'utc_offset': -10800,
#     'verified': True}},
#   {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Sun Apr 01 02:24:52 +0000 2018',
#    'entities': {'hashtags': [],
#     'media': [{'display_url': 'pic.twitter.com/w1XGwbuaVa',
#       'expanded_url': 'https://twitter.com/biobio/status/980269736452902913/photo/1',
#       'id': 980269696023965696,
#       'id_str': '980269696023965696',
#       'indices': [111, 134],
#       'media_url': 'http://pbs.twimg.com/media/DZqeGEeWsAANxl8.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/DZqeGEeWsAANxl8.jpg',
#       'sizes': {'large': {'h': 581, 'resize': 'fit', 'w': 1032},
#        'medium': {'h': 581, 'resize': 'fit', 'w': 1032},
#        'small': {'h': 383, 'resize': 'fit', 'w': 680},
#        'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#       'type': 'photo',
#       'url': 'https://t.co/w1XGwbuaVa'}],
#     'symbols': [],
#     'urls': [{'display_url': 'rbb.cl/jrsi',
#       'expanded_url': 'http://rbb.cl/jrsi',
#       'indices': [87, 110],
#       'url': 'https://t.co/U24yyLt1bw'}],
#     'user_mentions': []},
#    'extended_entities': {'media': [{'display_url': 'pic.twitter.com/w1XGwbuaVa',
#       'expanded_url': 'https://twitter.com/biobio/status/980269736452902913/photo/1',
#       'id': 980269696023965696,
#       'id_str': '980269696023965696',
#       'indices': [111, 134],
#       'media_url': 'http://pbs.twimg.com/media/DZqeGEeWsAANxl8.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/DZqeGEeWsAANxl8.jpg',
#       'sizes': {'large': {'h': 581, 'resize': 'fit', 'w': 1032},
#        'medium': {'h': 581, 'resize': 'fit', 'w': 1032},
#        'small': {'h': 383, 'resize': 'fit', 'w': 680},
#        'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#       'type': 'photo',
#       'url': 'https://t.co/w1XGwbuaVa'},
#      {'display_url': 'pic.twitter.com/w1XGwbuaVa',
#       'expanded_url': 'https://twitter.com/biobio/status/980269736452902913/photo/1',
#       'id': 980269696057528329,
#       'id_str': '980269696057528329',
#       'indices': [111, 134],
#       'media_url': 'http://pbs.twimg.com/media/DZqeGEmW0AkLmeu.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/DZqeGEmW0AkLmeu.jpg',
#       'sizes': {'large': {'h': 581, 'resize': 'fit', 'w': 1032},
#        'medium': {'h': 581, 'resize': 'fit', 'w': 1032},
#        'small': {'h': 383, 'resize': 'fit', 'w': 680},
#        'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#       'type': 'photo',
#       'url': 'https://t.co/w1XGwbuaVa'}]},
#    'favorite_count': 49,
#    'favorited': False,
#    'geo': None,
#    'id': 980269736452902913,
#    'id_str': '980269736452902913',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'es',
#    'metadata': {'iso_language_code': 'es', 'result_type': 'popular'},
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 18,
#    'retweeted': False,
#    'source': '<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>',
#    'text': 'Con actividades de visibilización conmemoran Día Internacional del Autismo en Valdivia https://t.co/U24yyLt1bw https://t.co/w1XGwbuaVa',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Sat May 03 15:15:06 +0000 2008',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': 'Cuéntanos todo lo que ocurre en tu ciudad  📲 ¿Tienes un video que quieras compartir? Envíalo al +56 9 8149 2444',
#     'entities': {'description': {'urls': []},
#      'url': {'urls': [{'display_url': 'biobiochile.cl',
#         'expanded_url': 'http://www.biobiochile.cl',
#         'indices': [0, 23],
#         'url': 'https://t.co/bwzwESePWa'}]}},
#     'favourites_count': 12295,
#     'follow_request_sent': False,
#     'followers_count': 2790146,
#     'following': True,
#     'friends_count': 16915,
#     'geo_enabled': True,
#     'has_extended_profile': True,
#     'id': 14638581,
#     'id_str': '14638581',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'es',
#     'listed_count': 10622,
#     'location': 'Chile',
#     'name': 'BioBioChile',
#     'notifications': False,
#     'profile_background_color': 'FFFFFF',
#     'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/378800000030294310/0d8b3c7001dc4de55d2a3d3f905707d3.png',
#     'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/378800000030294310/0d8b3c7001dc4de55d2a3d3f905707d3.png',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/14638581/1522665919',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/905753852552601602/9TN4W1_M_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/905753852552601602/9TN4W1_M_normal.jpg',
#     'profile_link_color': '029BB3',
#     'profile_sidebar_border_color': 'FFFFFF',
#     'profile_sidebar_fill_color': 'B5D7F2',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'biobio',
#     'statuses_count': 681296,
#     'time_zone': 'Santiago',
#     'translator_type': 'none',
#     'url': 'https://t.co/bwzwESePWa',
#     'utc_offset': -10800,
#     'verified': True}},
#   {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Sun Apr 01 02:18:28 +0000 2018',
#    'entities': {'hashtags': [],
#     'media': [{'display_url': 'pic.twitter.com/wAzSGAJt3U',
#       'expanded_url': 'https://twitter.com/Cooperativa/status/980268124791549952/photo/1',
#       'id': 980268122358910982,
#       'id_str': '980268122358910982',
#       'indices': [106, 129],
#       'media_url': 'http://pbs.twimg.com/media/DZqcqeHXkAYI8Yg.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/DZqcqeHXkAYI8Yg.jpg',
#       'sizes': {'large': {'h': 365, 'resize': 'fit', 'w': 649},
#        'medium': {'h': 365, 'resize': 'fit', 'w': 649},
#        'small': {'h': 365, 'resize': 'fit', 'w': 649},
#        'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#       'type': 'photo',
#       'url': 'https://t.co/wAzSGAJt3U'}],
#     'symbols': [],
#     'urls': [{'display_url': 'bit.ly/2H0yrS9',
#       'expanded_url': 'http://bit.ly/2H0yrS9',
#       'indices': [82, 105],
#       'url': 'https://t.co/J9GCYpfPlK'}],
#     'user_mentions': []},
#    'extended_entities': {'media': [{'display_url': 'pic.twitter.com/wAzSGAJt3U',
#       'expanded_url': 'https://twitter.com/Cooperativa/status/980268124791549952/photo/1',
#       'id': 980268122358910982,
#       'id_str': '980268122358910982',
#       'indices': [106, 129],
#       'media_url': 'http://pbs.twimg.com/media/DZqcqeHXkAYI8Yg.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/DZqcqeHXkAYI8Yg.jpg',
#       'sizes': {'large': {'h': 365, 'resize': 'fit', 'w': 649},
#        'medium': {'h': 365, 'resize': 'fit', 'w': 649},
#        'small': {'h': 365, 'resize': 'fit', 'w': 649},
#        'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#       'type': 'photo',
#       'url': 'https://t.co/wAzSGAJt3U'}]},
#    'favorite_count': 32,
#    'favorited': False,
#    'geo': None,
#    'id': 980268124791549952,
#    'id_str': '980268124791549952',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'es',
#    'metadata': {'iso_language_code': 'es', 'result_type': 'popular'},
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 21,
#    'retweeted': False,
#    'source': '<a href="http://www.cooperativa.cl" rel="nofollow">Cooperativa.cl</a>',
#    'text': 'Las Animas derrotó a Valdivia y se coronó campeón de la Conferencia Sur de la LNB https://t.co/J9GCYpfPlK https://t.co/wAzSGAJt3U',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Mon Jul 23 22:31:14 +0000 2007',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': 'Actualidad Online. Síguenos también en https://t.co/e9mG6blZ0c & https://t.co/wz1YhzqFLG               \n\nWhatsApp +56978880770',
#     'entities': {'description': {'urls': [{'display_url': 'fb.com/Cooperativa',
#         'expanded_url': 'http://fb.com/Cooperativa',
#         'indices': [39, 62],
#         'url': 'https://t.co/e9mG6blZ0c'},
#        {'display_url': 'instagram.com/Cooperativa',
#         'expanded_url': 'http://instagram.com/Cooperativa',
#         'indices': [65, 88],
#         'url': 'https://t.co/wz1YhzqFLG'}]},
#      'url': {'urls': [{'display_url': 'Cooperativa.cl',
#         'expanded_url': 'http://www.Cooperativa.cl/',
#         'indices': [0, 22],
#         'url': 'http://t.co/336Fb893SD'}]}},
#     'favourites_count': 1155,
#     'follow_request_sent': False,
#     'followers_count': 2658476,
#     'following': True,
#     'friends_count': 747084,
#     'geo_enabled': True,
#     'has_extended_profile': False,
#     'id': 7668952,
#     'id_str': '7668952',
#     'is_translation_enabled': True,
#     'is_translator': False,
#     'lang': 'es',
#     'listed_count': 8727,
#     'location': 'Santiago, Chile',
#     'name': 'Cooperativa',
#     'notifications': False,
#     'profile_background_color': '9AE4E8',
#     'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/378800000116812645/86ee923db2ab0f0bbf4376ebb70b631f.jpeg',
#     'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/378800000116812645/86ee923db2ab0f0bbf4376ebb70b631f.jpeg',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/7668952/1522793483',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/946028978103517184/7dyIRr1v_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/946028978103517184/7dyIRr1v_normal.jpg',
#     'profile_link_color': '0000FF',
#     'profile_sidebar_border_color': 'FFFFFF',
#     'profile_sidebar_fill_color': 'FAFDF5',
#     'profile_text_color': '000000',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'Cooperativa',
#     'statuses_count': 825375,
#     'time_zone': 'Santiago',
#     'translator_type': 'regular',
#     'url': 'http://t.co/336Fb893SD',
#     'utc_offset': -10800,
#     'verified': True}},
#   {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Mon Mar 26 16:53:10 +0000 2018',
#    'entities': {'hashtags': [],
#     'media': [{'display_url': 'pic.twitter.com/IPjwOLCP7u',
#       'expanded_url': 'https://twitter.com/biobio/status/978313924469813248/photo/1',
#       'id': 978313904999878656,
#       'id_str': '978313904999878656',
#       'indices': [89, 112],
#       'media_url': 'http://pbs.twimg.com/media/DZOrUDJX0AAaezV.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/DZOrUDJX0AAaezV.jpg',
#       'sizes': {'large': {'h': 720, 'resize': 'fit', 'w': 960},
#        'medium': {'h': 720, 'resize': 'fit', 'w': 960},
#        'small': {'h': 510, 'resize': 'fit', 'w': 680},
#        'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#       'type': 'photo',
#       'url': 'https://t.co/IPjwOLCP7u'}],
#     'symbols': [],
#     'urls': [{'display_url': 'rbb.cl/jq3f',
#       'expanded_url': 'http://rbb.cl/jq3f',
#       'indices': [65, 88],
#       'url': 'https://t.co/8RX6qbEnoV'}],
#     'user_mentions': []},
#    'extended_entities': {'media': [{'display_url': 'pic.twitter.com/IPjwOLCP7u',
#       'expanded_url': 'https://twitter.com/biobio/status/978313924469813248/photo/1',
#       'id': 978313904999878656,
#       'id_str': '978313904999878656',
#       'indices': [89, 112],
#       'media_url': 'http://pbs.twimg.com/media/DZOrUDJX0AAaezV.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/DZOrUDJX0AAaezV.jpg',
#       'sizes': {'large': {'h': 720, 'resize': 'fit', 'w': 960},
#        'medium': {'h': 720, 'resize': 'fit', 'w': 960},
#        'small': {'h': 510, 'resize': 'fit', 'w': 680},
#        'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#       'type': 'photo',
#       'url': 'https://t.co/IPjwOLCP7u'}]},
#    'favorite_count': 28,
#    'favorited': False,
#    'geo': None,
#    'id': 978313924469813248,
#    'id_str': '978313924469813248',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'es',
#    'metadata': {'iso_language_code': 'es', 'result_type': 'popular'},
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 18,
#    'retweeted': False,
#    'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#    'text': 'Seremi de Transportes confirma proyecto de Tranvía para Valdivia https://t.co/8RX6qbEnoV https://t.co/IPjwOLCP7u',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Sat May 03 15:15:06 +0000 2008',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': 'Cuéntanos todo lo que ocurre en tu ciudad  📲 ¿Tienes un video que quieras compartir? Envíalo al +56 9 8149 2444',
#     'entities': {'description': {'urls': []},
#      'url': {'urls': [{'display_url': 'biobiochile.cl',
#         'expanded_url': 'http://www.biobiochile.cl',
#         'indices': [0, 23],
#         'url': 'https://t.co/bwzwESePWa'}]}},
#     'favourites_count': 12295,
#     'follow_request_sent': False,
#     'followers_count': 2790146,
#     'following': True,
#     'friends_count': 16915,
#     'geo_enabled': True,
#     'has_extended_profile': True,
#     'id': 14638581,
#     'id_str': '14638581',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'es',
#     'listed_count': 10622,
#     'location': 'Chile',
#     'name': 'BioBioChile',
#     'notifications': False,
#     'profile_background_color': 'FFFFFF',
#     'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/378800000030294310/0d8b3c7001dc4de55d2a3d3f905707d3.png',
#     'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/378800000030294310/0d8b3c7001dc4de55d2a3d3f905707d3.png',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/14638581/1522665919',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/905753852552601602/9TN4W1_M_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/905753852552601602/9TN4W1_M_normal.jpg',
#     'profile_link_color': '029BB3',
#     'profile_sidebar_border_color': 'FFFFFF',
#     'profile_sidebar_fill_color': 'B5D7F2',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'biobio',
#     'statuses_count': 681296,
#     'time_zone': 'Santiago',
#     'translator_type': 'none',
#     'url': 'https://t.co/bwzwESePWa',
#     'utc_offset': -10800,
#     'verified': True}},
#   {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Sat Mar 31 20:54:16 +0000 2018',
#    'entities': {'hashtags': [{'indices': [98, 116],
#       'text': 'DaleAlboEsClasico'}],
#     'symbols': [],
#     'urls': [{'display_url': 'bit.ly/2GIZ2pf',
#       'expanded_url': 'http://bit.ly/2GIZ2pf',
#       'indices': [117, 140],
#       'url': 'https://t.co/MFMXjMoCqC'}],
#     'user_mentions': []},
#    'favorite_count': 145,
#    'favorited': False,
#    'geo': None,
#    'id': 980186540000333831,
#    'id_str': '980186540000333831',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'es',
#    'metadata': {'iso_language_code': 'es', 'result_type': 'popular'},
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 21,
#    'retweeted': False,
#    'source': '<a href="https://ifttt.com" rel="nofollow">IFTTT</a>',
#    'text': 'Mago Valdivia llama a darlo todo en la Libertadores: “Hay que jugar con mucho amor a la camiseta” #DaleAlboEsClasico https://t.co/MFMXjMoCqC',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Fri Apr 04 04:20:18 +0000 2008',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': 'Noticias de Colo Colo. En Internet también somos Chile desde hace 15 años',
#     'entities': {'description': {'urls': []},
#      'url': {'urls': [{'display_url': 'dalealbo.cl',
#         'expanded_url': 'http://www.dalealbo.cl',
#         'indices': [0, 23],
#         'url': 'https://t.co/loWDFec1yE'}]}},
#     'favourites_count': 816,
#     'follow_request_sent': False,
#     'followers_count': 185901,
#     'following': False,
#     'friends_count': 3860,
#     'geo_enabled': False,
#     'has_extended_profile': False,
#     'id': 14299778,
#     'id_str': '14299778',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'es',
#     'listed_count': 483,
#     'location': 'Santiago, Chile',
#     'name': 'DaleAlbo',
#     'notifications': False,
#     'profile_background_color': '1A1B1F',
#     'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/11770119/twitter_dalealbo.jpg',
#     'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/11770119/twitter_dalealbo.jpg',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/14299778/1520456649',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/971491581042876416/y0eGF80f_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/971491581042876416/y0eGF80f_normal.jpg',
#     'profile_link_color': 'ABB8C2',
#     'profile_sidebar_border_color': '181A1E',
#     'profile_sidebar_fill_color': '252429',
#     'profile_text_color': '666666',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'dalealbo',
#     'statuses_count': 64244,
#     'time_zone': 'Santiago',
#     'translator_type': 'none',
#     'url': 'https://t.co/loWDFec1yE',
#     'utc_offset': -10800,
#     'verified': True}}]}

# %% [markdown]
# ## 3. Conectarse al SGBD Mongo

# %% [markdown]
# - Conectarse a Mongo desde Python utilizando la librería adecuada

# %%
from pymongo import MongoClient
client = MongoClient('localhost', 27017)

# %% [markdown]
# ## 4. Escribir datos de Twitter en una Base de Datos Mongo

# %%
db=client.TP2
i=0
while i<len(json["statuses"]):
    print(json["statuses"][i]["created_at"])
    print(json["statuses"][i]["text"])
    print(json["statuses"][i]["user"]["name"])
    print(json["statuses"][i]["user"]["description"])
    print(json["statuses"][i]["user"]["location"])
    i += 1
    diccionario = { "created_at": json["statuses"][i]["created_at"],
                   "text": json["statuses"][i]["text"],
                   "name": json["statuses"][i]["user"]["name"],
                   "description": json["statuses"][i]["user"]["description"],
                   "location": json["statuses"][i]["user"]["location"]}
    db.reviews.insert_one(diccionario)
# Out:
# Tue Apr 03 18:13:31 +0000 2018
# Actividades mineras en el río Valdivia afectarían hábitat de cisnes de cuello negro https://t.co/XBEyh6f2oQ https://t.co/xIP5jxDRbh
# BioBioChile
# Cuéntanos todo lo que ocurre en tu ciudad  📲 ¿Tienes un video que quieras compartir? Envíalo al +56 9 8149 2444
# Chile
# Tue Apr 03 13:20:26 +0000 2018
# #Osorno será el primer lugar que visitaré en #Chile en mayo. Os espero allí el día 10 de ese mes, para comenzar est… https://t.co/6SGOWfVvVM
# Alex Ubago Oficial
# Bienvenidos a la cuenta oficial de ALEX UBAGO en Twitter. Facebook: Alex Ubago Music. Instagram: alexubagoficial. Booking: Get In (+34) 943 316911
# España
# Mon Apr 02 15:38:49 +0000 2018
# Valdívia inicia nova etapa na recuperação e trabalha no campo
#
# https://t.co/bVRc8i2YWk https://t.co/kVc42byt8p
# São Paulo FC
# Twitter oficial do Tricolor | EN: @SaoPauloFC_eng | ES: @SaoPauloFC_esp | snap: saopaulofc1930
# São Paulo
# Mon Apr 02 21:59:53 +0000 2018
# Sernageomin ordena paralizar obras de concesión minera en Río Valdivia y borde de humedal https://t.co/gNSoALPfx9 https://t.co/hmPTMeNFSD
# BioBioChile
# Cuéntanos todo lo que ocurre en tu ciudad  📲 ¿Tienes un video que quieras compartir? Envíalo al +56 9 8149 2444
# Chile
# Wed Apr 04 02:19:10 +0000 2018
# Hoy en el municipio de Valdivia firmamos el inicio de las obras de rehabilitación y pavimentación de la vía veredal… https://t.co/r7wAHWjmpQ
# Luis Pérez Gutiérrez
# Gobernador de Antioquia #PiensaEnGrande
# Medellín, Antioquia
# Tue Apr 03 20:28:03 +0000 2018
# Las reuniones de hoy con @FPCIUDADANA, Cámara Chilena de Centros Comerciales, @Movilh y el Alcalde de Valdivia, rea… https://t.co/JNwnEjVXgx
# S. Prevención Delito
# Cuenta oficial de la Subsecretaría de Prevención del Delito. Ministerio del Interior y Seguridad Pública.
# Chile
# Wed Apr 04 03:43:41 +0000 2018
# Municipio de Valdivia dispuso de $130 millones para arreglar calles mediante bacheo https://t.co/PqfuRRvgSl https://t.co/6YaRvvyb3W
# BioBioChile
# Cuéntanos todo lo que ocurre en tu ciudad  📲 ¿Tienes un video que quieras compartir? Envíalo al +56 9 8149 2444
# Chile
# Fri Mar 30 15:02:28 +0000 2018
# Informação: Valdivia não joga contra o Ateltico Paranaense, quarta, pela copa do Brasil. Jogador segue no DM tratan… https://t.co/pVXDCzhxCI
# André Hernan
# Jornalista, repórter do Grupo Globo, apaixonado por esportes e fuçador do mundo afora. Pai da Nina e do Bento. Também estou lá no https://t.co/BuCkWB73aR
# santiago, chile
# Sat Mar 31 14:00:02 +0000 2018
# ¿EL "MAGO" O EL "ENANO"?
#
# #CentralFOXChile @el_mago_oficial y @Diego_Buona se verán las caras en este nuevo Clásico… https://t.co/BbyCz2WnV3
# FOX Sports Chile
# Twitter oficial de FOX Sports Chile. El canal de deportes #1 en audiencia en Latinoamérica.
# Chile
# Sun Apr 01 14:14:41 +0000 2018
# De los 400 kilómetros más caros del mundo en peajes, sólo existe alrededor de 15 kms en doble calzada. Y existen 2… https://t.co/92cKkk7Sy0
# Alfredo Ramos Maya
# Defensor de la propiedad privada y la libertad individual, del emprendimiento, la ciencia y la transparencia
# Medellín, Colombia
# Thu Mar 29 19:04:06 +0000 2018
# Liturgia de oración con motivo de #SemanaSanta 2018 en el Campo Militar #Valdivia https://t.co/LhUYMpIzjZ
# Ejército de Chile
# Bienvenidos a la cuenta oficial del Ejército de Chile.
# Avenida Tupper 1725, CL
# Sun Apr 01 02:24:52 +0000 2018
# Con actividades de visibilización conmemoran Día Internacional del Autismo en Valdivia https://t.co/U24yyLt1bw https://t.co/w1XGwbuaVa
# BioBioChile
# Cuéntanos todo lo que ocurre en tu ciudad  📲 ¿Tienes un video que quieras compartir? Envíalo al +56 9 8149 2444
# Chile
# Sun Apr 01 02:18:28 +0000 2018
# Las Animas derrotó a Valdivia y se coronó campeón de la Conferencia Sur de la LNB https://t.co/J9GCYpfPlK https://t.co/wAzSGAJt3U
# Cooperativa
# Actualidad Online. Síguenos también en https://t.co/e9mG6blZ0c & https://t.co/wz1YhzqFLG
#
# WhatsApp +56978880770
# Santiago, Chile
# Mon Mar 26 16:53:10 +0000 2018
# Seremi de Transportes confirma proyecto de Tranvía para Valdivia https://t.co/8RX6qbEnoV https://t.co/IPjwOLCP7u
# BioBioChile
# Cuéntanos todo lo que ocurre en tu ciudad  📲 ¿Tienes un video que quieras compartir? Envíalo al +56 9 8149 2444
# Chile
# Sat Mar 31 20:54:16 +0000 2018
# Mago Valdivia llama a darlo todo en la Libertadores: “Hay que jugar con mucho amor a la camiseta” #DaleAlboEsClasico https://t.co/MFMXjMoCqC
# DaleAlbo
# Noticias de Colo Colo. En Internet también somos Chile desde hace 15 años
# Santiago, Chile
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-49-7871858b4516> in <module>()
#       8     print(json["statuses"][i]["user"]["location"])
#       9     i += 1
# ---> 10     diccionario = { "created_at": json["statuses"][i]["created_at"],
#      11                    "text": json["statuses"][i]["text"],
#      12                    "name": json["statuses"][i]["user"]["name"],
#
# IndexError: list index out of range
